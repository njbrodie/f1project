# %% [markdown]
# # EDA
# ### Jiyeon Song

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import seaborn as sns
import re


# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'  # Higher resolution figures

# %% [markdown]
# ## 1. Read CSVs
# * drivers.csv: to get the driver's name
# * results.csv: EDA

# %%
drivers_df = pd.read_csv("data/drivers.csv")
drivers_df
# Out:
#      driverId        driverRef number code  forename     surname         dob  \
# 0           1         hamilton     44  HAM     Lewis    Hamilton  1985-01-07
# 1           2         heidfeld     \N  HEI      Nick    Heidfeld  1977-05-10
# 2           3          rosberg      6  ROS      Nico     Rosberg  1985-06-27
# 3           4           alonso     14  ALO  Fernando      Alonso  1981-07-29
# 4           5       kovalainen     \N  KOV    Heikki  Kovalainen  1981-10-19
# ..        ...              ...    ...  ...       ...         ...         ...
# 852       854  mick_schumacher     47  MSC      Mick  Schumacher  1999-03-22
# 853       855             zhou     24  ZHO    Guanyu        Zhou  1999-05-30
# 854       856         de_vries     45  DEV      Nyck    de Vries  1995-02-06
# 855       857          piastri     81  PIA     Oscar     Piastri  2001-04-06
# 856       858         sargeant      2  SAR     Logan    Sargeant  2000-12-31
#
#     nationality                                             url
# 0       British     http://en.wikipedia.org/wiki/Lewis_Hamilton
# 1        German      http://en.wikipedia.org/wiki/Nick_Heidfeld
# 2        German       http://en.wikipedia.org/wiki/Nico_Rosberg
# 3       Spanish    http://en.wikipedia.org/wiki/Fernando_Alonso
# 4       Finnish  http://en.wikipedia.org/wiki/Heikki_Kovalainen
# ..          ...                                             ...
# 852      German    http://en.wikipedia.org/wiki/Mick_Schumacher
# 853     Chinese        http://en.wikipedia.org/wiki/Guanyu_Zhou
# 854       Dutch      http://en.wikipedia.org/wiki/Nyck_de_Vries
# 855  Australian      http://en.wikipedia.org/wiki/Oscar_Piastri
# 856    American     http://en.wikipedia.org/wiki/Logan_Sargeant
#
# [857 rows x 9 columns]

# %%
results_df = pd.read_csv("data/results.csv")
results_df
# Out:
#        resultId  raceId  driverId  constructorId number  grid position  \
# 0             1      18         1              1     22     1        1
# 1             2      18         2              2      3     5        2
# 2             3      18         3              3      7     7        3
# 3             4      18         4              4      5    11        4
# 4             5      18         5              1     23     3        5
# ...         ...     ...       ...            ...    ...   ...      ...
# 25835     25841    1096       854            210     47    12       16
# 25836     25842    1096       825            210     20    16       17
# 25837     25843    1096         1            131     44     5       18
# 25838     25844    1096       849              3      6    20       19
# 25839     25845    1096         4            214     14    10       \N
#
#       positionText  positionOrder  points  laps         time milliseconds  \
# 0                1              1    10.0    58  1:34:50.616      5690616
# 1                2              2     8.0    58       +5.478      5696094
# 2                3              3     6.0    58       +8.163      5698779
# 3                4              4     5.0    58      +17.181      5707797
# 4                5              5     4.0    58      +18.014      5708630
# ...            ...            ...     ...   ...          ...          ...
# 25835           16             16     0.0    57           \N           \N
# 25836           17             17     0.0    57           \N           \N
# 25837           18             18     0.0    55           \N           \N
# 25838           19             19     0.0    55           \N           \N
# 25839            R             20     0.0    27           \N           \N
#
#       fastestLap rank fastestLapTime fastestLapSpeed  statusId
# 0             39    2       1:27.452         218.300         1
# 1             41    3       1:27.739         217.586         1
# 2             41    5       1:28.090         216.719         1
# 3             58    7       1:28.603         215.464         1
# 4             43    1       1:27.418         218.385         1
# ...          ...  ...            ...             ...       ...
# 25835         39   12       1:29.833         211.632        11
# 25836         40   20       1:31.158         208.556        11
# 25837         42   11       1:29.788         211.738         9
# 25838         45   14       1:30.309         210.517       130
# 25839         24   17       1:30.579         209.889        47
#
# [25840 rows x 18 columns]

# %% [markdown]
# ## 2. Clean each dataframes

# %%
drivers_df = drivers_df[['driverId', 'code', 'forename', 'surname']]
drivers_df
# Out:
#      driverId code  forename     surname
# 0           1  HAM     Lewis    Hamilton
# 1           2  HEI      Nick    Heidfeld
# 2           3  ROS      Nico     Rosberg
# 3           4  ALO  Fernando      Alonso
# 4           5  KOV    Heikki  Kovalainen
# ..        ...  ...       ...         ...
# 852       854  MSC      Mick  Schumacher
# 853       855  ZHO    Guanyu        Zhou
# 854       856  DEV      Nyck    de Vries
# 855       857  PIA     Oscar     Piastri
# 856       858  SAR     Logan    Sargeant
#
# [857 rows x 4 columns]

# %%
results_df = results_df[['resultId', 'raceId', 'driverId', 'position', 'points', 'time', 'rank', 'fastestLapTime', 'fastestLapSpeed']]
results_df
# Out:
#        resultId  raceId  driverId position  points         time rank  \
# 0             1      18         1        1    10.0  1:34:50.616    2
# 1             2      18         2        2     8.0       +5.478    3
# 2             3      18         3        3     6.0       +8.163    5
# 3             4      18         4        4     5.0      +17.181    7
# 4             5      18         5        5     4.0      +18.014    1
# ...         ...     ...       ...      ...     ...          ...  ...
# 25835     25841    1096       854       16     0.0           \N   12
# 25836     25842    1096       825       17     0.0           \N   20
# 25837     25843    1096         1       18     0.0           \N   11
# 25838     25844    1096       849       19     0.0           \N   14
# 25839     25845    1096         4       \N     0.0           \N   17
#
#       fastestLapTime fastestLapSpeed
# 0           1:27.452         218.300
# 1           1:27.739         217.586
# 2           1:28.090         216.719
# 3           1:28.603         215.464
# 4           1:27.418         218.385
# ...              ...             ...
# 25835       1:29.833         211.632
# 25836       1:31.158         208.556
# 25837       1:29.788         211.738
# 25838       1:30.309         210.517
# 25839       1:30.579         209.889
#
# [25840 rows x 9 columns]

# %%
driv_results = drivers_df.merge(results_df, on="driverId")
driv_results
# Out:
#        driverId code forename   surname  resultId  raceId position  points  \
# 0             1  HAM    Lewis  Hamilton         1      18        1    10.0
# 1             1  HAM    Lewis  Hamilton        27      19        5     4.0
# 2             1  HAM    Lewis  Hamilton        57      20       13     0.0
# 3             1  HAM    Lewis  Hamilton        69      21        3     6.0
# 4             1  HAM    Lewis  Hamilton        90      22        2     8.0
# ...         ...  ...      ...       ...       ...     ...      ...     ...
# 25835       855  ZHO   Guanyu      Zhou     25777    1093       12     0.0
# 25836       855  ZHO   Guanyu      Zhou     25798    1094       13     0.0
# 25837       855  ZHO   Guanyu      Zhou     25817    1095       12     0.0
# 25838       855  ZHO   Guanyu      Zhou     25837    1096       12     0.0
# 25839       856  DEV     Nyck  de Vries     25714    1089        9     2.0
#
#               time rank fastestLapTime fastestLapSpeed
# 0      1:34:50.616    2       1:27.452         218.300
# 1          +46.548    3       1:35.462         209.033
# 2               \N   19       1:35.520         203.969
# 3           +4.187    3       1:22.017         204.323
# 4           +3.779    2       1:26.529         222.085
# ...            ...  ...            ...             ...
# 25835    +1:16.164   15       1:42.471         193.682
# 25836           \N    7       1:22.260         188.358
# 25837      +29.325   17       1:15.802         204.643
# 25838           \N    8       1:29.600         212.183
# 25839       +7.122   13       1:26.624         240.750
#
# [25840 rows x 12 columns]

# %%
driv_results.dtypes
# [ideal data types after cleaning]
# driverId - int64
# code - object
# forename - object
# surname - object
# resultId - int64
# raceId - int64
# position - int64
# points - int64
# time - object
# rank - int64
# fastestLapTime - object
# fastestLapSpeed - object
# Out:
# driverId             int64
# code                object
# forename            object
# surname             object
# resultId             int64
# raceId               int64
# position            object
# points             float64
# time                object
# rank                object
# fastestLapTime      object
# fastestLapSpeed     object
# dtype: object

# %%
# need to handle some missing values. But not sure how to replace that \N
results_df.replace(r'\\N', np.nan, regex = True)
# Out:
#        resultId  raceId  driverId position  points         time rank  \
# 0             1      18         1        1    10.0  1:34:50.616    2
# 1             2      18         2        2     8.0       +5.478    3
# 2             3      18         3        3     6.0       +8.163    5
# 3             4      18         4        4     5.0      +17.181    7
# 4             5      18         5        5     4.0      +18.014    1
# ...         ...     ...       ...      ...     ...          ...  ...
# 25835     25841    1096       854       16     0.0          NaN   12
# 25836     25842    1096       825       17     0.0          NaN   20
# 25837     25843    1096         1       18     0.0          NaN   11
# 25838     25844    1096       849       19     0.0          NaN   14
# 25839     25845    1096         4      NaN     0.0          NaN   17
#
#       fastestLapTime fastestLapSpeed
# 0           1:27.452         218.300
# 1           1:27.739         217.586
# 2           1:28.090         216.719
# 3           1:28.603         215.464
# 4           1:27.418         218.385
# ...              ...             ...
# 25835       1:29.833         211.632
# 25836       1:31.158         208.556
# 25837       1:29.788         211.738
# 25838       1:30.309         210.517
# 25839       1:30.579         209.889
#
# [25840 rows x 9 columns]

# %%
driv_results["rank"].astype(int)#.groupby('driverId').median()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\jyson\ds_projects_2023\f1project\EDA_Song.ipynb Cell 11 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/jyson/ds_projects_2023/f1project/EDA_Song.ipynb#X15sZmlsZQ%3D%3D?line=0'>1</a> driv_results["rank"].astype(int)
#
# File c:\Users\jyson\anaconda3\lib\site-packages\pandas\core\generic.py:5912, in NDFrame.astype(self, dtype, copy, errors)
#    5905     results = [
#    5906         self.iloc[:, i].astype(dtype, copy=copy)
#    5907         for i in range(len(self.columns))
#    5908     ]
#    5910 else:
#    5911     # else, only a single dtype is given
# -> 5912     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913     return self._constructor(new_data).__finalize__(self, method="astype")
#    5915 # GH 33113: handle empty frame or series
#
# File c:\Users\jyson\anaconda3\lib\site-packages\pandas\core\internals\managers.py:419, in BaseBlockManager.astype(self, dtype, copy, errors)
#     418 def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 419     return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#
# File c:\Users\jyson\anaconda3\lib\site-packages\pandas\core\internals\managers.py:304, in BaseBlockManager.apply(self, f, align_keys, ignore_failures, **kwargs)
#     302         applied = b.apply(f, **kwargs)
#     303     else:
# --> 304         applied = getattr(b, f)(**kwargs)
#     305 except (TypeError, NotImplementedError):
#     306     if not ignore_failures:
#
# File c:\Users\jyson\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:580, in Block.astype(self, dtype, copy, errors)
#     562 """
#     563 Coerce to the new dtype.
#     564
#    (...)
#     576 Block
#     577 """
#     578 values = self.values
# --> 580 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     582 new_values = maybe_coerce_values(new_values)
#     583 newb = self.make_block(new_values)
#
# File c:\Users\jyson\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py:1292, in astype_array_safe(values, dtype, copy, errors)
#    1289     dtype = dtype.numpy_dtype
#    1291 try:
# -> 1292     new_values = astype_array(values, dtype, copy=copy)
#    1293 except (ValueError, TypeError):
#    1294     # e.g. astype_nansafe can fail on object-dtype of strings
#    1295     #  trying to convert to float
#    1296     if errors == "ignore":
#
# File c:\Users\jyson\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py:1237, in astype_array(values, dtype, copy)
#    1234     values = values.astype(dtype, copy=copy)
#    1236 else:
# -> 1237     values = astype_nansafe(values, dtype, copy=copy)
#    1239 # in pandas we don't store numpy str dtypes, so convert to object
#    1240 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File c:\Users\jyson\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py:1154, in astype_nansafe(arr, dtype, copy, skipna)
#    1150 elif is_object_dtype(arr.dtype):
#    1151
#    1152     # work around NumPy brokenness, #1987
#    1153     if np.issubdtype(dtype.type, np.integer):
# -> 1154         return lib.astype_intsafe(arr, dtype)
#    1156     # if we have a datetime/timedelta array of objects
#    1157     # then coerce to a proper dtype and recall astype_nansafe
#    1159     elif is_datetime64_dtype(dtype):
#
# File c:\Users\jyson\anaconda3\lib\site-packages\pandas\_libs\lib.pyx:668, in pandas._libs.lib.astype_intsafe()
#
# ValueError: invalid literal for int() with base 10: '\\N'

# %% [markdown]
# ## Interesting Finding

# %%
# scatter plot for top 5 drivers' trend change from position(start) to result(end) - not perfect
sns.scatterplot(data = driv_results, x = 'position', y = 'rank', hue = 'driverId', style = 'code')
# Out:
# <AxesSubplot:xlabel='position', ylabel='rank'>
